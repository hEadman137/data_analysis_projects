# %% [markdown]
# # Анализ крупного интернет магазина

# %% [markdown]
# В нашем распоряжении три датафрейма с данными о гипотезах для их приоритизации, данные о заказах и основная информация о пользователя нашего интернет магазина. Вместе с отделом маркетинга мы подготовим список гипотез для увеличения выручки.
# Приоритизируем гипотезы, запустим A/B-тест и проанализируем результаты.
#
# **Цель исследования:**
# 1. Приоритизация гипотез.
# * Применить фреймворк ICE для приоритизации гипотез. Отсортировать их по убыванию приоритета.
# * Применить фреймворк RICE для приоритизации гипотез. Отсортировать их по убыванию приоритета.
# * Указать, как изменилась приоритизация гипотез при применении RICE вместо ICE.
#
# 2. Анализ A/B-теста.
# * Построить график кумулятивной выручки по группам.
# * Построить график кумулятивного среднего чека по группам.
# * Построить график относительного изменения кумулятивного среднего чека группы B к группе A.
# * Построить график кумулятивного среднего количества заказов на посетителя по группам.
# * Построить график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.
# * Построить точечный график количества заказов по пользователям.
# * Посчитать 95-й и 99-й перцентили количества заказов на пользователя. Выбрать границу для определения аномальных пользователей.
# * Построить точечный график стоимостей заказов.
# * Посчитать 95-й и 99-й перцентили стоимости заказов. Выбрать границу для определения аномальных заказов.
# * Посчитать статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.
# * Посчитать статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.
# * Посчитать статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным.
# * Посчитать статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным.
# * Cделать вывод.
#
#
# **Ход исследования:**
# 1. В первую очередь, необходимо выгрузить все данные, а также их предобработать: проверить на неявные/явные дубликаты, пропуски; правильно проименовать столбцы.
# 2. Применим фреймворк ICE для приоритизации гипотез. Отсортируем их по убыванию приоритета. Выявим самую важную и менее важную гипотезу.
# 3. Применим фреймворк RICE для приоритизации гипотез. Отсортируем их по убыванию приоритета. Выявим самую важную и менее важную гипотезу.
# 4. Указаем, как изменилась приоритизация гипотез при применении RICE вместо ICE.
# 5. Построим график кумулятивной выручки по группам.
# 6. Построим график кумулятивного среднего чека по группам.
# 7. Построим график относительного изменения кумулятивного среднего чека группы B к группе A.
# 8. Построим график кумулятивного среднего количества заказов на посетителя по группам.
# 9. Построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.
# 10. Построим точечный график количества заказов по пользователям.
# 11. Посчитаем 95-й и 99-й перцентили количества заказов на пользователя. Выбрать границу для определения аномальных пользователей.Построить точечный график стоимостей заказов.
# 12. Посчитаем 95-й и 99-й перцентили стоимости заказов. Выбрать границу для определения аномальных заказов.
# 13. Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.
# 14. Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.
# 15. Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным.
# 16. Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным.
# 17. Напишем вывод.
#
#
# **Предоставленные данные:**
#
#
# Данные о гипотезах представляют из себя: краткое описание гипотез, Reach, Impact, Confidence и Effort показатели:
# * **hypothesis** — краткое описание гипотезы;
# * **reach** — охват пользователей по 10-балльной шкале;
# * **impact** — влияние на пользователей по 10-балльной шкале;
# * **confidence** — уверенность в гипотезе по 10-балльной шкале;
# * **efforts** — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.
#
#
#
# Данные о заказах представляют из себя: идентификатор заказа; идентификатор пользователя, совершившего заказ; дата, когда был совершён заказ; выручка заказа; группа A/B-теста, в которую попал заказ.
# * **transaction_id** — идентификатор заказа;
# * **visitor_id** — идентификатор пользователя, совершившего заказ;
# * **date** — дата, когда был совершён заказ;
# * **revenue** — выручка заказа;
# * **group** — группа A/B-теста, в которую попал заказ.
#
#
#
# Данные о посетителях представляют из себя: date — дата; группа A/B-теста; количество пользователей в указанную дату в указанной группе A/B-теста.
# * **date** — дата;
# * **group** — группа A/B-теста;
# * **visitors** — количество пользователей в указанную дату в указанной группе A/B-теста

# %% [markdown]
# # Анализ крупного интернет магазина

# %% [markdown]
# В нашем распоряжении три датафрейма с данными о гипотезах для их приоритизации, данные о заказах и основная информация о пользователя нашего интернет магазина. Вместе с отделом маркетинга мы подготовим список гипотез для увеличения выручки.
# Приоритизируем гипотезы, запустим A/B-тест и проанализируем результаты.
#
# **Цель исследования:**
# 1. Приоритизация гипотез.
# * Применить фреймворк ICE для приоритизации гипотез. Отсортировать их по убыванию приоритета.
# * Применить фреймворк RICE для приоритизации гипотез. Отсортировать их по убыванию приоритета.
# * Указать, как изменилась приоритизация гипотез при применении RICE вместо ICE.
#
# 2. Анализ A/B-теста.
# * Построить график кумулятивной выручки по группам.
# * Построить график кумулятивного среднего чека по группам.
# * Построить график относительного изменения кумулятивного среднего чека группы B к группе A.
# * Построить график кумулятивного среднего количества заказов на посетителя по группам.
# * Построить график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.
# * Построить точечный график количества заказов по пользователям.
# * Посчитать 95-й и 99-й перцентили количества заказов на пользователя. Выбрать границу для определения аномальных пользователей.
# * Построить точечный график стоимостей заказов.
# * Посчитать 95-й и 99-й перцентили стоимости заказов. Выбрать границу для определения аномальных заказов.
# * Посчитать статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.
# * Посчитать статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.
# * Посчитать статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным.
# * Посчитать статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным.
# * Cделать вывод.
#
#
# **Ход исследования:**
# 1. В первую очередь, необходимо выгрузить все данные, а также их предобработать: проверить на неявные/явные дубликаты, пропуски; правильно проименовать столбцы.
# 2. Применим фреймворк ICE для приоритизации гипотез. Отсортируем их по убыванию приоритета. Выявим самую важную и менее важную гипотезу.
# 3. Применим фреймворк RICE для приоритизации гипотез. Отсортируем их по убыванию приоритета. Выявим самую важную и менее важную гипотезу.
# 4. Указаем, как изменилась приоритизация гипотез при применении RICE вместо ICE.
# 5. Построим график кумулятивной выручки по группам.
# 6. Построим график кумулятивного среднего чека по группам.
# 7. Построим график относительного изменения кумулятивного среднего чека группы B к группе A.
# 8. Построим график кумулятивного среднего количества заказов на посетителя по группам.
# 9. Построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.
# 10. Построим точечный график количества заказов по пользователям.
# 11. Посчитаем 95-й и 99-й перцентили количества заказов на пользователя. Выбрать границу для определения аномальных пользователей.Построить точечный график стоимостей заказов.
# 12. Посчитаем 95-й и 99-й перцентили стоимости заказов. Выбрать границу для определения аномальных заказов.
# 13. Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.
# 14. Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.
# 15. Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным.
# 16. Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным.
# 17. Напишем вывод.
#
#
# **Предоставленные данные:**
#
#
# Данные о гипотезах представляют из себя: краткое описание гипотез, Reach, Impact, Confidence и Effort показатели:
# * **hypothesis** — краткое описание гипотезы;
# * **reach** — охват пользователей по 10-балльной шкале;
# * **impact** — влияние на пользователей по 10-балльной шкале;
# * **confidence** — уверенность в гипотезе по 10-балльной шкале;
# * **efforts** — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.
#
#
#
# Данные о заказах представляют из себя: идентификатор заказа; идентификатор пользователя, совершившего заказ; дата, когда был совершён заказ; выручка заказа; группа A/B-теста, в которую попал заказ.
# * **transaction_id** — идентификатор заказа;
# * **visitor_id** — идентификатор пользователя, совершившего заказ;
# * **date** — дата, когда был совершён заказ;
# * **revenue** — выручка заказа;
# * **group** — группа A/B-теста, в которую попал заказ.
#
#
#
# Данные о посетителях представляют из себя: date — дата; группа A/B-теста; количество пользователей в указанную дату в указанной группе A/B-теста.
# * **date** — дата;
# * **group** — группа A/B-теста;
# * **visitors** — количество пользователей в указанную дату в указанной группе A/B-теста

# %% [markdown]
# ## Загрузим данные и подготовим их к анализу.

# %% [markdown]
# ### Импортируем нужные модули.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# ### Загрузим данные.

# %% [markdown]
# #### Загрузим данные о приоритизации гипотез.

# %% [markdown]
# 1. С помощью метода read_csv() выгрузим нужный датасет.

# %%
data_h = pd.read_csv('/datasets/hypothesis.csv')
data_h.head(5)
# Out:
#                                           Hypothesis  Reach  Impact  \
# 0  Добавить два новых канала привлечения трафика,...      3      10
# 1  Запустить собственную службу доставки, что сок...      2       5
# 2  Добавить блоки рекомендаций товаров на сайт ин...      8       3
# 3  Изменить структура категорий, что увеличит кон...      8       3
# 4  Изменить цвет фона главной страницы, чтобы уве...      3       1
#
#    Confidence  Efforts
# 0           8        6
# 1           4       10
# 2           7        3
# 3           3        8
# 4           1        1

# %% [markdown]
# **Вывод:** из выведенных данных можем заметить, что формат названий столбцов выбран неверно, необходимо исправить.

# %% [markdown]
# 2. С помощью метода rename() изменим названия столбцов.

# %%
data_h = data_h.rename(columns={"Hypothesis": "hypothesis", "Reach": "reach", "Impact": "impact", "Confidence": "confidence", "Efforts": "efforts"})
pd.options.display.max_colwidth = 150

# %%
data_h
# Out:
#                                                                                                      hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %% [markdown]
# #### Загрузим данные о совершенных заказах.

# %% [markdown]
# 1. С помощью метода read_csv() выгрузим нужный датасет.

# %%
data_o = pd.read_csv('/datasets/orders.csv')
data_o
# Out:
#       transactionId   visitorId        date  revenue group
# 0        3667963787  3312258926  2019-08-15     1650     B
# 1        2804400009  3642806036  2019-08-15      730     B
# 2        2961555356  4069496402  2019-08-15      400     A
# 3        3797467345  1196621759  2019-08-15     9759     B
# 4        2282983706  2322279887  2019-08-15     2308     B
# ...             ...         ...         ...      ...   ...
# 1192     2662137336  3733762160  2019-08-14     6490     B
# 1193     2203539145   370388673  2019-08-14     3190     A
# 1194     1807773912   573423106  2019-08-14    10550     A
# 1195     1947021204  1614305549  2019-08-14      100     A
# 1196     3936777065  2108080724  2019-08-15   202740     B
#
# [1197 rows x 5 columns]

# %% [markdown]
# **Вывод:** из выведенных данных можем заметить, что формат названий некоторых столбцов выбран неверно, необходимо исправить.

# %%
data_o.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB

# %% [markdown]
# 2. Исправим названия столбцов на верный формат.

# %%
data_o = data_o.rename(columns={'transactionId':'transaction_id', 'visitorId':'visitor_id'})
data_o
# Out:
#       transaction_id  visitor_id        date  revenue group
# 0         3667963787  3312258926  2019-08-15     1650     B
# 1         2804400009  3642806036  2019-08-15      730     B
# 2         2961555356  4069496402  2019-08-15      400     A
# 3         3797467345  1196621759  2019-08-15     9759     B
# 4         2282983706  2322279887  2019-08-15     2308     B
# ...              ...         ...         ...      ...   ...
# 1192      2662137336  3733762160  2019-08-14     6490     B
# 1193      2203539145   370388673  2019-08-14     3190     A
# 1194      1807773912   573423106  2019-08-14    10550     A
# 1195      1947021204  1614305549  2019-08-14      100     A
# 1196      3936777065  2108080724  2019-08-15   202740     B
#
# [1197 rows x 5 columns]

# %% [markdown]
# 3. Проверим датафрейм на наличие дубликатов.

# %%
data_o.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Вывод:** дубликаты отсутствуют.

# %% [markdown]
# 4. Проверим датафрейм на наличие пропусков.

# %%
data_o.isna().sum()
# Out:
# transaction_id    0
# visitor_id        0
# date              0
# revenue           0
# group             0
# dtype: int64

# %% [markdown]
# **Вывод:** пропуски отсутствуют.

# %% [markdown]
# #### Загрузим данные о пользователях.

# %% [markdown]
# 1. С помощью метода read_csv() выгрузим нужный датасет.

# %%
data_v = pd.read_csv('/datasets/visitors.csv')
data_v
# Out:
#           date group  visitors
# 0   2019-08-01     A       719
# 1   2019-08-02     A       619
# 2   2019-08-03     A       507
# 3   2019-08-04     A       717
# 4   2019-08-05     A       756
# ..         ...   ...       ...
# 57  2019-08-27     B       720
# 58  2019-08-28     B       654
# 59  2019-08-29     B       531
# 60  2019-08-30     B       490
# 61  2019-08-31     B       718
#
# [62 rows x 3 columns]

# %% [markdown]
# 2. Проверим на наличие дубликатов.

# %%
data_v.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Вывод:** дубликаты отсутствуют.

# %% [markdown]
# 3. Проверим на наличие пропусков.

# %%
data_v.isna().sum()
# Out:
# date        0
# group       0
# visitors    0
# dtype: int64

# %% [markdown]
# **Вывод:** пропуски отсутствуют.

# %% [markdown]
# #### Проверим, есть ли пользователи, которые попали по ошибке в обе группы теста.

# %% [markdown]
# 1. Найдем количество таких пользователей, которые оказались в обоих группах.

# %%
data_o.groupby('visitor_id').agg({'group' : 'nunique'}).query('group > 1').count()
# Out:
# group    58
# dtype: int64

# %% [markdown]
# **Вывод:** в датафрейме присутствует 58 пользователей, которые попали сразу в обе группы при проведении теста. Количество не такое большое, поэтому предлагаю их оставить, сильно оно не повлияет на наш анализ.

# %% [markdown]
# **Общий вывод по разделу:** в данном разделе мы загрузили все датасеты и предобработали их. Датасеты готовы для дальнейшего анализа.

# %% [markdown]
# ## Приоритизация гипотез.

# %% [markdown]
# ### Применим фреймворк ICE для приоритизации гипотез.

# %% [markdown]
# 1. Создадим новый столбец 'ICE' в датасете 'data_h', в который запишем приоритет каждой гипотезы.

# %%
data_h['ICE'] = (data_h['impact'] * data_h['confidence']) / data_h['efforts']
data_h
# Out:
#                                                                                                      hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %% [markdown]
# 2. Отсортируем полученную таблицу по приоритету 'ICE' и выведем только два столбца с названием и приоритетом.

# %%
ice_table = data_h[['hypothesis', 'ICE']].sort_values(by='ICE', ascending=False)
ice_table = np.round(ice_table, 2)
ice_table
# Out:
#                                                                                                      hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# **Вывод:** по выведенной таблице видно, что наибольший приоритет у гипотезы, связанной с запуском акции. Также, не менее важной гипотезой является добавление двух новых каналов привлечения трафика и добавление формы подписки на все основные страницы. Менее всего приоритет у гипотезы, связанной с изменением цвета фона главной страницы.

# %% [markdown]
# ### Применим фреймворк RICE для приоритизации гипотез.

# %% [markdown]
# 1. Создадим новый столбец 'RICE' в датасете 'data_h', в который запишем приоритет каждой гипотезы.

# %%
data_h['RICE'] = (data_h['reach'] * data_h['impact'] * data_h['confidence']) / data_h['efforts']
data_h
# Out:
#                                           hypothesis  reach  impact  \
# 0  Добавить два новых канала привлечения трафика,...      3      10
# 1  Запустить собственную службу доставки, что сок...      2       5
# 2  Добавить блоки рекомендаций товаров на сайт ин...      8       3
# 3  Изменить структура категорий, что увеличит кон...      8       3
# 4  Изменить цвет фона главной страницы, чтобы уве...      3       1
# 5  Добавить страницу отзывов клиентов о магазине,...      3       2
# 6  Показать на главной странице баннеры с актуаль...      5       3
# 7  Добавить форму подписки на все основные страни...     10       7
# 8  Запустить акцию, дающую скидку на товар в день...      1       9
#
#    confidence  efforts        ICE   RICE
# 0           8        6  13.333333   40.0
# 1           4       10   2.000000    4.0
# 2           7        3   7.000000   56.0
# 3           3        8   1.125000    9.0
# 4           1        1   1.000000    3.0
# ...

# %% [markdown]
# 2. Отсортируем полученную таблицу по приоритету 'RICE' и выведем только два столбца с названием и приоритетом.

# %%
rice_table = data_h[['hypothesis', 'RICE']].sort_values(by='RICE', ascending=False)
rice_table
# Out:
#                                           hypothesis   RICE
# 7  Добавить форму подписки на все основные страни...  112.0
# 2  Добавить блоки рекомендаций товаров на сайт ин...   56.0
# 0  Добавить два новых канала привлечения трафика,...   40.0
# 6  Показать на главной странице баннеры с актуаль...   40.0
# 8  Запустить акцию, дающую скидку на товар в день...   16.2
# 3  Изменить структура категорий, что увеличит кон...    9.0
# 1  Запустить собственную службу доставки, что сок...    4.0
# 5  Добавить страницу отзывов клиентов о магазине,...    4.0
# 4  Изменить цвет фона главной страницы, чтобы уве...    3.0

# %% [markdown]
# **Вывод:** по выведенной таблице видно, что наибольший приоритет с большой разницой у гипотезы, связанной с добавлением формы подписки на все основные страницы. Также, не менее важными гипотезами являются добавление блока рекомендаций товара, добавление двух новых каналов привлечения трафика и показ на главной странице баннеров с актуальными акциями. Менее всего приоритет у гипотезы, связанной с изменением цвета фона главной страницы.

# %% [markdown]
# ### Изменение приоритизации гипотез при применении RICE вместо ICE.

# %% [markdown]
# 1. Для наглядности выведем обе таблицы.

# %%
ice_table
# Out:
#                                           hypothesis        ICE
# 8  Запустить акцию, дающую скидку на товар в день...  16.200000
# 0  Добавить два новых канала привлечения трафика,...  13.333333
# 7  Добавить форму подписки на все основные страни...  11.200000
# 6  Показать на главной странице баннеры с актуаль...   8.000000
# 2  Добавить блоки рекомендаций товаров на сайт ин...   7.000000
# 1  Запустить собственную службу доставки, что сок...   2.000000
# 5  Добавить страницу отзывов клиентов о магазине,...   1.333333
# 3  Изменить структура категорий, что увеличит кон...   1.125000
# 4  Изменить цвет фона главной страницы, чтобы уве...   1.000000

# %%
rice_table
# Out:
#                                           hypothesis   RICE
# 7  Добавить форму подписки на все основные страни...  112.0
# 2  Добавить блоки рекомендаций товаров на сайт ин...   56.0
# 0  Добавить два новых канала привлечения трафика,...   40.0
# 6  Показать на главной странице баннеры с актуаль...   40.0
# 8  Запустить акцию, дающую скидку на товар в день...   16.2
# 3  Изменить структура категорий, что увеличит кон...    9.0
# 1  Запустить собственную службу доставки, что сок...    4.0
# 5  Добавить страницу отзывов клиентов о магазине,...    4.0
# 4  Изменить цвет фона главной страницы, чтобы уве...    3.0

# %% [markdown]
# **Фреймворк ICE состоит из трёх компонент:**
# * Impact — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# * Confidence — насколько вы уверены, что это изменение повлияет на пользователей именно так;
# * Efforts — сколько стоит протестировать эту гипотезу.
#
#
# **Фреймворк RICE состоит из четырёх компонент:**
# * Reach — скольких пользователей затронет изменение, которое вы хотите внести;
# * Impact — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# * Confidence — насколько вы уверены, что это изменение повлияет на пользователей именно так;
# * Efforts — сколько стоит протестировать эту гипотезу.
#
#
# Во фреймворке ICE не учитывается компонент Reach, который показывает скольких пользователей затронет изменение. Поэтому в таблицах показатели отличаются.
#
#
# Рассмотрим таблицу с фреймворком RICE. Мы видим, что самый наибольший приоритет у гипотезы, связанной с добавлением формы подписки на все основные страницы (112 пунктов). Мы понимаем, что если мы добавляем какой-либо элемент на основную страницу, то обновление затронет практически всех пользователей сайта, поэтому приоритет растет. Если мы взглянем на таблицу с фреймворком ICE, то заметим, что данная гипотеза занимает только третье место по приоритету, так как показатель Reach не был учтён.

# %% [markdown]
# ## Анализ A/B-теста.

# %% [markdown]
# ### Анализ групп, которые участвовали в A/B тестирование.

# %% [markdown]
# 1. Узнаем сколько групп участвовали в А/В тестировании.

# %%
data_v['group'].unique()
# Out:
# array(['A', 'B'], dtype=object)

# %% [markdown]
# **Вывод:** в А/В тестировании участвовали две группы, тест является парным.

# %% [markdown]
# 2. Узнаем начало и окончание A/B теста.

# %%
# Столбец 'date' преобразуем тип данных object в date
data_o['date'] = pd.to_datetime(data_o['date'], format='%Y-%m-%d')

# %%
print ('Начало A/B теста:', data_o['date'].min(),'\n Конец A/B теста:', data_o['date'].max() )
# Out:
# Начало A/B теста: 2019-08-01 00:00:00
#  Конец A/B теста: 2019-08-31 00:00:00

# %% [markdown]
# **Вывод:** A/B тест длился один месяц. С 1 августа 2019 по 31 августа 2019.

# %% [markdown]
# 3. Узнаем количество уникальных пользователей в обоих группах.

# %%
data_o.groupby('group').agg({'visitor_id': ['nunique']})
# Out:
#       visitor_id
#          nunique
# group
# A            503
# B            586

# %% [markdown]
# **Вывод:** в группе А - 503 уникальных пользователя, в группе В - 586 уникальных пользователей. Различие группы в ±6%.

# %% [markdown]
# ### Построим график кумулятивной выручки по группам.

# %% [markdown]
# 1. Объединим обе таблицы (data_o и data_v) в одну с понятными названиями столбцов.

# %%
# создаем массив уникальных пар значений дат и групп теста
datesGroups = data_o[['date','group']].drop_duplicates()

# получаем агрегированные кумулятивные по дням данные о заказах 
ordersAggregated = datesGroups.apply(lambda x: data_o[np.logical_and(data_o['date'] <= x['date'], data_o['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'transaction_id' : 'nunique', 'visitor_id' : 'nunique', 'revenue' : 'sum'}), axis=1).sort_values(by=['date','group'])

# получаем агрегированные кумулятивные по дням данные о посетителях интернет-магазина 
visitorsAggregated = datesGroups.apply(lambda x: data_v[np.logical_and(data_v['date'] <= x['date'], data_v['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group'])

# объединяем кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия
cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# %% [markdown]
# 2. На основе объединенной таблицы строим график.

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
plt.figure(figsize=(15, 6))
plt.grid()
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]

# Строим график выручки группы А
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')

# Строим график выручки группы B
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')

# Настройка меток оси x
plt.xticks(rotation=45)  # поворот меток на 45 градусов
plt.xticks(cumulativeRevenueA['date'][::7])

# Настройка названий осей
plt.title('График кумулятивной выручки по группам')
plt.xlabel('Дата')
plt.ylabel('Выручка, тыс. руб.')

plt.legend()
plt.show();

# %% [markdown]
# **Вывод:** по выведенному графику мы видим, что группа А в течение всего времени стабильно растет без координальных скачков по показателям, предполагаю, что эта группа не подверагалсь каким-либо изменениям или не было совершено аномальных покупок. По графику, показывающего выручку группы В, мы видим, что присуствует скачок в уровне выручки за короткий промежуток времени, возможно, в этот период, было введено обновление, которое промотивировало пользователей купить товары в нашем интернет магазине или же в этот промежуток времени были совершены аномальные заказы, отличные от средних показателей.

# %% [markdown]
# ### Построим график кумулятивного среднего чека по группам.

# %% [markdown]
# 1. Чтобы определить средний чек, необходимо выручку по дням разделить на количество заказов. Нарисуем график.

# %%
# Строим график
plt.figure(figsize=(15, 6))
plt.grid()
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'] / cumulativeRevenueA['orders'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'] / cumulativeRevenueB['orders'], label='B')

# Настройка названий осей
plt.title('График кумулятивного среднего чека по группам')
plt.xlabel('Дата')
plt.ylabel('Средний чек')

# Настройка меток оси x
plt.xticks(rotation=45)  # поворот меток на 45 градусов
plt.xticks(cumulativeRevenueA['date'][::7])
plt.legend() 
plt.show();

# %% [markdown]
# **Вывод:** по выведенному графику мы видим, что показатели среднего чека группы А с начала периода анализа падают до минимума, менее 5000, затем начинают стремительно расти до отметки ±7500 (максимум), затем ситуация по показателям стабилизируется и средний чек держится примерно на одном и том же уровне. Ситуация с группой В иная - в начале периода анализа показатель среднего чека постепенно растет, также, встречаются несущественные просадки по показателям. Но за короткий промежуток времени, показатель среднего чека возрастает на ±3000, могу предположить, что в этот промежуток времени вышло какое-то обновление, которое заинтересовало клиентов купить товар в нашем интернет магазине или же в этот промежуток времени были совершены аномальные заказы, отличные от средних показателей.

# %% [markdown]
# ### Построим график относительного изменения кумулятивного среднего чека группы B к группе A.

# %%
# собираем данные в одном датафрейме
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

# cтроим отношение средних чеков
plt.figure(figsize=(15, 6))
plt.grid()

# Настройка названий осей
plt.title('График относительного изменения кумулятивного среднего чека группы B к группе A')
plt.xlabel('Дата')
plt.ylabel('Доля')
plt.plot(mergedCumulativeRevenue['date'], (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])/(mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1)

# добавляем ось X
plt.axhline(y=0, color='black', linestyle='--') 

# Настройка меток оси x
plt.xticks(rotation=45)  # поворот меток на 45 градусов
plt.xticks(cumulativeRevenueA['date'][::7])
plt.show();

# %% [markdown]
# **Вывод:** В нескольких точках график различия между сегментами резко «скачет», видимо тогда были совершены аномальные заказы. Но в основном график расположен выше нуля.

# %% [markdown]
# ### Построим график кумулятивного среднего количества заказов на посетителя по группам.

# %%
# считаем кумулятивную конверсию
cumulativeData['conversion'] = cumulativeData['orders']/cumulativeData['visitors']

# отделяем данные по группе A
cumulativeDataA = cumulativeData[cumulativeData['group']=='A']

# отделяем данные по группе B
cumulativeDataB = cumulativeData[cumulativeData['group']=='B']

# строим графики
plt.figure(figsize=(15, 6))
plt.grid()

plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label='A')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label='B')

# Настройка названий осей
plt.title('График кумулятивного среднего количества заказов на посетителя по группам')
plt.xlabel('Дата')
plt.ylabel('Среднее количество заказов на пользователя')

# Настройка меток оси x
plt.xticks(rotation=45)  # поворот меток на 45 градусов
plt.xticks(cumulativeRevenueA['date'][::7])
plt.legend()
plt.show();

# %% [markdown]
# **Вывод:** по выведенному графику, мы можем заметить, что среднее количеством заказов на посетителя группы B выше, чем у А. В начале периода анализа мы видим, что у группы A большой скачок по показателям, выше, чем у группы B, но в течение короткого времени показатели снижаются и держатся на уровне от 0.029 - 0.031. У группы В cитуация иная - после скачка вниз, показатели повышаются и держатся на уровне 0.033 - 0.036.

# %% [markdown]
# ### Построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе А.

# %%
mergedCumulativeConversions = cumulativeDataA[['date','conversion']].merge(cumulativeDataB[['date','conversion']], left_on='date', right_on='date', how='left', suffixes=['A', 'B'])
#строим график
plt.figure(figsize=(15, 10))
plt.plot(mergedCumulativeConversions['date'], mergedCumulativeConversions['conversionB']/mergedCumulativeConversions['conversionA']-1, label="Относительный прирост конверсии группы B относительно группы A")
# добавляем оси
plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=0.15, color='grey', linestyle='--')
plt.title('График относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A')
plt.xlabel('Дата')
plt.ylabel('Среднее количество заказов на посетителя')
# Настройка меток оси x
plt.xticks(rotation=45)  # поворот меток на 45 градусов
plt.xticks(cumulativeRevenueA['date'][::7])

plt.legend()
plt.grid()
plt.show();

# %% [markdown]
# **Вывод:** по графику видно, что примерно на 5 день, показатель относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе А начинает лидировать, приимерно на 15%.

# %% [markdown]
# ### Построим точечный график количества заказов по пользователям.

# %%
ordersByUsers = (
    data_o.groupby('visitor_id', as_index=False)
    .agg({'transaction_id': 'nunique'})
)
ordersByUsers.columns = ['userId', 'orders']

# серия из чисел от 0 до количества наблюдений в ordersByUsers
x_values = pd.Series(range(0, len(ordersByUsers)))

# Строим график
plt.figure(figsize=(10, 7))
plt.grid()
plt.scatter(x_values, ordersByUsers['orders']) 

# Настройка названий осей
plt.title('Точечный график количества заказов по пользователям')
plt.xlabel('Частота')
plt.ylabel('Количество заказов')
plt.show();

# %% [markdown]
# **Вывод:** по графику видно, что количество пользователей, совершивших больше двух заказов не так много, стоит задуматься над привлечением пользователей совершать больше заказов.

# %% [markdown]
# ### Посчитаем 95-й и 99-й перцентили количества заказов на пользователя.

# %% [markdown]
# 1. С помощью метода np.percentile() найдем 5-й и 99-й перцентили количества заказов на пользователя.

# %%
print(np.percentile(ordersByUsers['orders'], [95, 99]))
# Out:
# [2. 4.]

# %% [markdown]
# **Вывод:** менее 5% пользователей совершили более 2 заказов, а менее 1% пользователей сделали более 4 заказов. В качестве границы для фильтра аномалий возьмем значение, когда пользователь сделал более 3 заказов.

# %%
data_o
# Out:
#       transaction_id  visitor_id        date  revenue group
# 0         3667963787  3312258926  2019-08-15     1650     B
# 1         2804400009  3642806036  2019-08-15      730     B
# 2         2961555356  4069496402  2019-08-15      400     A
# 3         3797467345  1196621759  2019-08-15     9759     B
# 4         2282983706  2322279887  2019-08-15     2308     B
# ...              ...         ...         ...      ...   ...
# 1192      2662137336  3733762160  2019-08-14     6490     B
# 1193      2203539145   370388673  2019-08-14     3190     A
# 1194      1807773912   573423106  2019-08-14    10550     A
# 1195      1947021204  1614305549  2019-08-14      100     A
# 1196      3936777065  2108080724  2019-08-15   202740     B
#
# [1197 rows x 5 columns]

# %% [markdown]
# ### Построим точечный график стоимостей заказов.

# %%
x_values = pd.Series(range(0, len(data_o['revenue'])))
plt.figure(figsize=(10, 7))
plt.scatter(x_values, data_o['revenue']) 
plt.show();

# %% [markdown]
# **Вывод:** по графику видно, что в данных присутствуют аномалии - заказы на 1.2 млн. руб. и 200 тыс. руб.

# %% [markdown]
# ### Посчитаем 95-й и 99-й перцентили стоимости заказов.

# %%
print(np.percentile(data_o['revenue'] , [95, 99]))
# Out:
# [28000.  58233.2]

# %% [markdown]
# **Вывод:** из выведенных данных видим, что 5% пользователей заказали товаров на более чем 28.000 рублей, а 1% пользователей приобрели товаров в нашем магазине на сумму выше 58233.2 рублей. В качестве границы для фильтра аномалий возьмем значения более 40.000 руб.

# %%
data_o
# Out:
#       transaction_id  visitor_id        date  revenue group
# 0         3667963787  3312258926  2019-08-15     1650     B
# 1         2804400009  3642806036  2019-08-15      730     B
# 2         2961555356  4069496402  2019-08-15      400     A
# 3         3797467345  1196621759  2019-08-15     9759     B
# 4         2282983706  2322279887  2019-08-15     2308     B
# ...              ...         ...         ...      ...   ...
# 1192      2662137336  3733762160  2019-08-14     6490     B
# 1193      2203539145   370388673  2019-08-14     3190     A
# 1194      1807773912   573423106  2019-08-14    10550     A
# 1195      1947021204  1614305549  2019-08-14      100     A
# 1196      3936777065  2108080724  2019-08-15   202740     B
#
# [1197 rows x 5 columns]

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.

# %% [markdown]
# 1. Сформулируем гипотезы.
#
# * H0: различий в среднем количестве заказов на посетителя между группами нет.
# * H1: различия в среднем количестве заказов на посетителя между группами есть.
# * Уровень значимости альфа = 0.05
# * В качестве критерия возьмём U-критерий Манна-Уитни. Ключевая идея — проранжировать две выборки по порядку от меньшего к большему и сравнить ранги одних и тех же значений, попавших в обе выборки.

# %%
visitorsADaily = data_v[data_v['group'] == 'A'][['date', 'visitors']]
visitorsADaily.columns = ['date', 'visitorsPerDateA']

visitorsACummulative = visitorsADaily.apply(
    lambda x: visitorsADaily[visitorsADaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateA': 'sum'}
    ),
    axis=1,
)
visitorsACummulative.columns = ['date', 'visitorsCummulativeA']

visitorsBDaily = data_v[data_v['group'] == 'B'][['date', 'visitors']]
visitorsBDaily.columns = ['date', 'visitorsPerDateB']

visitorsBCummulative = visitorsBDaily.apply(
    lambda x: visitorsBDaily[visitorsBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateB': 'sum'}
    ),
    axis=1,
)
visitorsBCummulative.columns = ['date', 'visitorsCummulativeB']

ordersADaily = (
    data_o[data_o['group'] == 'A'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
ordersADaily.columns = ['date', 'ordersPerDateA', 'revenuePerDateA']

ordersACummulative = ordersADaily.apply(
    lambda x: ordersADaily[ordersADaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateA': 'sum', 'revenuePerDateA': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersACummulative.columns = [
    'date',
    'ordersCummulativeA',
    'revenueCummulativeA',
]

ordersBDaily = (
    data_o[data_o['group'] == 'B'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
ordersBDaily.columns = ['date', 'ordersPerDateB', 'revenuePerDateB']

ordersBCummulative = ordersBDaily.apply(
    lambda x: ordersBDaily[ordersBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateB': 'sum', 'revenuePerDateB': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersBCummulative.columns = [
    'date',
    'ordersCummulativeB',
    'revenueCummulativeB',
]

data = (
    ordersADaily.merge(
        ordersBDaily, left_on='date', right_on='date', how='left'
    )
    .merge(ordersACummulative, left_on='date', right_on='date', how='left')
    .merge(ordersBCummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsADaily, left_on='date', right_on='date', how='left')
    .merge(visitorsBDaily, left_on='date', right_on='date', how='left')
    .merge(visitorsACummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsBCummulative, left_on='date', right_on='date', how='left')
)

print(data.head(5))
# Out:
#          date  ordersPerDateA  revenuePerDateA  ordersPerDateB  \
# 0  2019-08-01              24           148579              21
# 1  2019-08-02              20            93822              24
# 2  2019-08-03              24           112473              16
# 3  2019-08-04              16            70825              17
# 4  2019-08-05              25           124218              23
#
#    revenuePerDateB  ordersCummulativeA  revenueCummulativeA  \
# 0           101217                  24               148579
# 1           165531                  44               242401
# 2           114248                  68               354874
# 3           108571                  84               425699
# 4            92428                 109               549917
#
#    ordersCummulativeB  revenueCummulativeB  visitorsPerDateA  \
# 0                  21               101217               719
# 1                  45               266748               619
# ...

# %% [markdown]
# * ordersPerDateA — количество заказов в выбранную дату в группе A;
# * revenuePerDateA — суммарная выручка в выбранную дату в группе A;
# * ordersPerDateB — количество заказов в выбранную дату в группе B;
# * revenuePerDateB — суммарная выручка в выбранную дату в группе B;
# * ordersCummulativeA — суммарное число заказов до выбранной даты включительно в группе A;
# * revenueCummulativeA — суммарная выручка до выбранной даты включительно в группе A;
# * ordersCummulativeB — суммарное количество заказов до выбранной даты включительно в группе B;
# * revenueCummulativeB — суммарная выручка до выбранной даты включительно в группе B;
# * visitorsPerDateA — количество пользователей в выбранную дату в группе A;
# * visitorsPerDateB — количество пользователей в выбранную дату в группе B;
# * visitorsCummulativeA — количество пользователей до выбранной даты включительно в группе A;
# * visitorsCummulativeB — количество пользователей до выбранной даты включительно в группе B.

# %% [markdown]
# 2. Создадим переменные ordersByUsersA и ordersByUsersB со столбцами ['visitor_id', 'orders']. В них для пользователей, которые заказывали хотя бы 1 раз, укажем число совершённых заказов.

# %%
ordersByUsersA = (
    data_o[data_o['group'] == 'A']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
ordersByUsersA.columns = ['visitor_id', 'orders']

ordersByUsersB = (
    data_o[data_o['group'] == 'B']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
ordersByUsersB.columns = ['visitor_id', 'orders']

# %% [markdown]
# 3. Объявим переменные sampleA и sampleB, в которых пользователям из разных групп будет соответствовать количество заказов. Тем, кто ничего не заказал, будут соответствовать нули. Это нужно, чтобы подготовить выборки к проверке критерием Манна-Уитни.

# %%
sampleA = pd.concat(
    [
        ordersByUsersA['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleB = pd.concat(
    [
        ordersByUsersB['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

print("P-value: {0:.3f}".format(stats.mannwhitneyu(sampleA, sampleB)[1]))

print("Относительная разница среднего чека между сегментами: {0:.3f}".format(sampleB.mean() / sampleA.mean() - 1))
# Out:
# P-value: 0.017
# Относительная разница среднего чека между сегментами: 0.138

# %% [markdown]
# **Вывод:** P-value меньше 0.05 — это меньше заданного уровня значимости. Разница между выборками имеет значимый характер. Следовательно можно утверждать, что разница в среднем количестве заказов на посетителя между группами есть. Тот результат, который имеет на графике не может быть получен случайно. Относительное различие среднего чека между сегментами 13.8%

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.

# %% [markdown]
# 1. Сформулируем гипотезы.
#
# * H0: различий в среднем чеке между группами нет.
# * H1: различия в среднем чеке между группами есть.
# * Уровень значимости альфа = 0.05

# %% [markdown]
# 2. Чтобы рассчитать статистическую значимость различий в среднем чеке, передадим критерию mannwhitneyu() данные о выручке с заказов.

# %%
print('P-value: {0:.3f}'.format(stats.mannwhitneyu(data_o[data_o['group']=='A']['revenue'], data_o[data_o['group']=='B']['revenue'])[1]))
print('Относительный прирост группы В по среднему чеку заказа: {0:.3f}'.format(data_o[data_o['group']=='B']['revenue'].mean()/data_o[data_o['group']=='A']['revenue'].mean()-1))
# Out:
# P-value: 0.729
# Относительный прирост группы В по среднему чеку заказа: 0.259

# %% [markdown]
# **Вывод:** P-value значительно больше 0.05. Значит, причин отвергать нулевую гипотезу и считать, что в среднем чеке есть различия, нет. Относительный прирост группы В по среднему чеку заказа составил 25.9%.

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным.

# %% [markdown]
# 1. Примем за аномальных пользователей тех, кто совершил от 3 заказов или совершил заказ дороже 40 000 рублей. Так мы уберём 2.5% пользователей с наибольшим числом заказов и 2.5% пользователей с дорогими заказами.

# %%
usersWithManyOrders = pd.concat(
    [
        ordersByUsersA[ordersByUsersA['orders'] > 3]['visitor_id'],
        ordersByUsersB[ordersByUsersB['orders'] > 3]['visitor_id'],
    ],
    axis=0,
)
usersWithExpensiveOrders = data_o[data_o['revenue'] > 40000]['visitor_id']
abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)
print(abnormalUsers.head(5))
print(abnormalUsers.shape[0])
# Out:
# 1099    148427295
# 18      199603092
# 23      237748145
# 684     358944393
# 648     382846391
# Name: visitor_id, dtype: int64
# 34

# %% [markdown]
# Всего 34 аномальных visitor_id в нашем датасете.

# %% [markdown]
# 2. Найдём относительные потери.

# %%
unique_visitors = data_o['visitor_id'].unique().size
unique_visitors
# Out:
# 1031

# %%
looses = abnormalUsers.size / unique_visitors
looses
# Out:
# 0.03297769156159069

# %% [markdown]
# **Вывод:** относительные потери составили порядка ± 3,2%.

# %% [markdown]
# 2. Посчитаем статистическую значимость различий в среднем количестве заказов между группами теста по очищенным данным. Сначала подготовим выборки количества заказов по пользователям по группам теста:

# %%
sampleAFiltered = pd.concat(
    [
        ordersByUsersA[
            np.logical_not(ordersByUsersA['visitor_id'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleBFiltered = pd.concat(
    [
        ordersByUsersB[
            np.logical_not(ordersByUsersB['visitor_id'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# %% [markdown]
# 3. Применим статистический критерий Манна-Уитни к полученным выборкам.

# %%
print('{0:.3f}'.format(stats.mannwhitneyu(sampleAFiltered, sampleBFiltered)[1]))
print('{0:.3f}'.format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# 0.009
# 0.164

# %% [markdown]
# **Вывод:** Аномалии не повлияли на статистическую значимость. По очищенным данным P-value уменьшился с 1.7%% до 0.9%.
# Относительный прирост группы В к группе А увеличился с 13.8% до 16.4%

# %% [markdown]
# ### Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным.

# %%
print(
    '{0:.3f}'.format(
        stats.mannwhitneyu(
            data_o[
                np.logical_and(
                    data_o['group'] == 'A',
                    np.logical_not(data_o['visitor_id'].isin(abnormalUsers)),
                )
            ]['revenue'],
            data_o[
                np.logical_and(
                    data_o['group'] == 'B',
                    np.logical_not(data_o['visitor_id'].isin(abnormalUsers)),
                )
            ]['revenue'],
        )[1]
    )
)

print(
    "{0:.3f}".format(
        data_o[
            np.logical_and(
                data_o['group'] == 'B',
                np.logical_not(data_o['visitor_id'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        / data_o[
            np.logical_and(
                data_o['group'] == 'A',
                np.logical_not(data_o['visitor_id'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# 0.711
# 0.060

# %% [markdown]
# **Вывод:** Статистической разницы между "очищенными" и "сырыми" данными нет. p_value уменьшился с 72.9% до 71.1%
# Относительный прирост группы В к группе А уменьшился с 26% до 6%

# %% [markdown]
# ## Вывод. Принятие решения по результатам теста.

# %% [markdown]
# **1. В ходе исследования данных, связанных с интернет магазином была проделана большая работа:**
# * В первую очередь мы загрузили все данные и их предобработали.
# *  Датафреймы были проверены на явные/неявные дубликаты, а также на пропуски.
# * Некорректные названия столбцов были изменены на правильные.
#
# **2. Были выбраны самые приоритетные гипотезы с помощью RICE и ICE фреймворков:**
# * Наибольший приоритет у гипотезы ICE фреймворка, связанной с запуском акции. Также, не менее важной гипотезой является добавление двух новых каналов привлечения трафика и добавление формы подписки на все основные страницы. Менее всего приоритет у гипотезы, связанной с изменением цвета фона главной страницы.
# * Наибольший приоритет с большой разницой у гипотезы, связанной с добавлением формы подписки на все основные страницы. Также, не менее важными гипотезами являются добавление блока рекомендаций товара, добавление двух новых каналов привлечения трафика и показ на главной странице баннеров с актуальными акциями. Менее всего приоритет у гипотезы, связанной с изменением цвета фона главной страницы.
#
#
# **Фреймворк ICE состоит из трёх компонент:**
# * Impact — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# * Confidence — насколько вы уверены, что это изменение повлияет на пользователей именно так;
# * Efforts — сколько стоит протестировать эту гипотезу.
#
#
# **Фреймворк RICE состоит из четырёх компонент:**
# * Reach — скольких пользователей затронет изменение, которое вы хотите внести;
# * Impact — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# * Confidence — насколько вы уверены, что это изменение повлияет на пользователей именно так;
# * Efforts — сколько стоит протестировать эту гипотезу.
#
#
# **Вывод:** во фреймворке ICE не учитывается компонент Reach, который показывает скольких пользователей затронет изменение. Поэтому в таблицах показатели отличаются.
#
#
#
# **3. Провели анализ А/В теста и можем сделать выводы:**
#
#
# **По графикам кумулятивного расчета:**
# * **График кумулятивной выручки по группам.** Показатели выручки группы А в течение всего времени стабильно растут без координальных скачков по показателям, предполагаю, что эта группа не подверагалсь каким-либо изменениям или не было совершено аномальных покупок. По графику, показывающего кумулятивную выручку группы присуствует скачок в уровне выручки за короткий промежуток времени, возможно, в этот период, было введено обновление, которое промотивировало пользователей купить товары в нашем интернет магазине или же в этот промежуток времени были совершены аномальные заказы, отличные от средних показателей.
# * **График кумулятивного среднего чека по группам.** Показатели среднего чека группы А с начала периода анализа падают до минимума, менее 5000, затем начинают стремительно расти до отметки ±7500 (максимум), затем ситуация по показателям стабилизируется и средний чек держится примерно на одном и том же уровне. Ситуация с группой В иная - в начале периода анализа показатель среднего чека постепенно растет, также, встречаются несущественные просадки по показателям. Но за короткий промежуток времени, показатель среднего чека возрастает на ±3000, могу предположить, что в этот промежуток времени вышло какое-то обновление, которое заинтересовало клиентов купить товар в нашем интернет магазине или же в этот промежуток времени были совершены аномальные заказы, отличные от средних показателей.
# * **График относительного изменения кумулятивного среднего чека группы B к группе A.** В нескольких точках график различия между группами резко «скачет», видимо тогда были совершены аномальные заказы.
# * **График кумулятивного среднего количества заказов на посетителя по группам.** Среднее количество заказов на посетителя по группе B выше, чем у А. В начале периода анализа мы видим, что у группы A большой скачок по показателям, выше, чем у группы B, но в течение короткого времени показатели снижаются и держатся на уровне от 0.029 - 0.031. У группы В cитуация иная - после скачка вниз, показатели повышаются и держатся на уровне 0.033 - 0.036.
# * **График кумулятивного среднего количества заказов на посетителя по группам.** Примерно на 5 день, показатель кумулятивного среднего количества заказов на посетителя у группы В начинает лидировать, приимерно на 15%.
# * **Точечный график количества заказов по пользователям.** Количество пользователей, совершивших больше двух заказов не так много, стоит задуматься над привлечением пользователей совершать больше заказов.
#
#
#
# **Была подсчитана статистическая значимость различий в среднем чеке заказа между группами по «очищенным» и "сырым" данным:**
#
# * Статистической разницы между "очищенными" и "сырыми" данными нет. p_value уменьшился с 72.9% до 71.1%.
# * Относительный прирост группы В к группе А уменьшился с 26% до 6%
#
#
# **Была подсчитана статистическая значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» и "сырым" данным:**
#
# * Аномалии особо не повлияли на статистическую значимость. По очищенным данным p_value уменьшился с 1.7% до 0.9%
# * Относительный прирост группы В к группе А увеличился с 13.8% до 16.4%
#
#
# **Имеющиеся факты:**
# * Есть статистически значимое различие по среднему количеству заказов между группами и по «сырым», и по данным после фильтрации аномалий.
# * Нет статистически значимого различия по среднему чеку между группами ни по «сырым», ни по данным после фильтрации аномалий.
# * График различия среднего количества заказов между группами сообщает, что результаты группы B лучше группы A, но есть небольшая тенденция к ухудшению.
# * График различия среднего чека говорит о том, что результаты группы B имеет резкие колебания в течение всего периода.
# * По результатам исследования, можно утверждать, что различия среднего количества заказов между группами имеют статистическую значимость. То есть разница получена не случайным образом, а она действительно есть. Таким образом, количество заказов увеличилось, а средний чек остался прежним. Выручка увеличивается.
#
# **Ключевой вывод:** Исходя из обнаруженных фактов, тест следует остановить и зафиксировать победу группы В.

# %% [markdown]
# ## Загрузим данные и подготовим их к анализу.

# %% [markdown]
# ### Импортируем нужные модули.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# ### Загрузим данные.

# %% [markdown]
# #### Загрузим данные о приоритизации гипотез.

# %% [markdown]
# 1. С помощью метода read_csv() выгрузим нужный датасет.

# %%
data_h = pd.read_csv('/datasets/hypothesis.csv')
data_h.head(5)
# Out:
#                                           Hypothesis  Reach  Impact  \
# 0  Добавить два новых канала привлечения трафика,...      3      10
# 1  Запустить собственную службу доставки, что сок...      2       5
# 2  Добавить блоки рекомендаций товаров на сайт ин...      8       3
# 3  Изменить структура категорий, что увеличит кон...      8       3
# 4  Изменить цвет фона главной страницы, чтобы уве...      3       1
#
#    Confidence  Efforts
# 0           8        6
# 1           4       10
# 2           7        3
# 3           3        8
# 4           1        1

# %% [markdown]
# **Вывод:** из выведенных данных можем заметить, что формат названий столбцов выбран неверно, необходимо исправить.

# %% [markdown]
# 2. С помощью метода rename() изменим названия столбцов.

# %%
data_h = data_h.rename(columns={"Hypothesis": "hypothesis", "Reach": "reach", "Impact": "impact", "Confidence": "confidence", "Efforts": "efforts"})

# %%
data_h
# Out:
#                                           hypothesis  reach  impact  \
# 0  Добавить два новых канала привлечения трафика,...      3      10
# 1  Запустить собственную службу доставки, что сок...      2       5
# 2  Добавить блоки рекомендаций товаров на сайт ин...      8       3
# 3  Изменить структура категорий, что увеличит кон...      8       3
# 4  Изменить цвет фона главной страницы, чтобы уве...      3       1
# 5  Добавить страницу отзывов клиентов о магазине,...      3       2
# 6  Показать на главной странице баннеры с актуаль...      5       3
# 7  Добавить форму подписки на все основные страни...     10       7
# 8  Запустить акцию, дающую скидку на товар в день...      1       9
#
#    confidence  efforts
# 0           8        6
# 1           4       10
# 2           7        3
# 3           3        8
# 4           1        1
# 5           2        3
# 6           8        3
# 7           8        5
# 8           9        5

# %% [markdown]
# #### Загрузим данные о совершенных заказах.

# %% [markdown]
# 1. С помощью метода read_csv() выгрузим нужный датасет.

# %%
data_o = pd.read_csv('/datasets/orders.csv')
data_o
# Out:
#       transactionId   visitorId        date  revenue group
# 0        3667963787  3312258926  2019-08-15     1650     B
# 1        2804400009  3642806036  2019-08-15      730     B
# 2        2961555356  4069496402  2019-08-15      400     A
# 3        3797467345  1196621759  2019-08-15     9759     B
# 4        2282983706  2322279887  2019-08-15     2308     B
# ...             ...         ...         ...      ...   ...
# 1192     2662137336  3733762160  2019-08-14     6490     B
# 1193     2203539145   370388673  2019-08-14     3190     A
# 1194     1807773912   573423106  2019-08-14    10550     A
# 1195     1947021204  1614305549  2019-08-14      100     A
# 1196     3936777065  2108080724  2019-08-15   202740     B
#
# [1197 rows x 5 columns]

# %% [markdown]
# **Вывод:** из выведенных данных можем заметить, что формат названий некоторых столбцов выбран неверно, необходимо исправить.

# %%
data_o.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB

# %% [markdown]
# 2. Исправим названия столбцов на верный формат.

# %%
data_o = data_o.rename(columns={'transactionId':'transaction_id', 'visitorId':'visitor_id'})
data_o
# Out:
#       transaction_id  visitor_id        date  revenue group
# 0         3667963787  3312258926  2019-08-15     1650     B
# 1         2804400009  3642806036  2019-08-15      730     B
# 2         2961555356  4069496402  2019-08-15      400     A
# 3         3797467345  1196621759  2019-08-15     9759     B
# 4         2282983706  2322279887  2019-08-15     2308     B
# ...              ...         ...         ...      ...   ...
# 1192      2662137336  3733762160  2019-08-14     6490     B
# 1193      2203539145   370388673  2019-08-14     3190     A
# 1194      1807773912   573423106  2019-08-14    10550     A
# 1195      1947021204  1614305549  2019-08-14      100     A
# 1196      3936777065  2108080724  2019-08-15   202740     B
#
# [1197 rows x 5 columns]

# %% [markdown]
# 3. Проверим датафрейм на наличие дубликатов.

# %%
data_o.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Вывод:** дубликаты отсутствуют.

# %% [markdown]
# 4. Проверим датафрейм на наличие пропусков.

# %%
data_o.isna().sum()
# Out:
# transaction_id    0
# visitor_id        0
# date              0
# revenue           0
# group             0
# dtype: int64

# %% [markdown]
# **Вывод:** пропуски отсутствуют.

# %% [markdown]
# #### Загрузим данные о пользователях.

# %% [markdown]
# 1. С помощью метода read_csv() выгрузим нужный датасет.

# %%
data_v = pd.read_csv('/datasets/visitors.csv')
data_v
# Out:
#           date group  visitors
# 0   2019-08-01     A       719
# 1   2019-08-02     A       619
# 2   2019-08-03     A       507
# 3   2019-08-04     A       717
# 4   2019-08-05     A       756
# ..         ...   ...       ...
# 57  2019-08-27     B       720
# 58  2019-08-28     B       654
# 59  2019-08-29     B       531
# 60  2019-08-30     B       490
# 61  2019-08-31     B       718
#
# [62 rows x 3 columns]

# %% [markdown]
# 2. Проверим на наличие дубликатов.

# %%
data_v.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Вывод:** дубликаты отсутствуют.

# %% [markdown]
# 3. Проверим на наличие пропусков.

# %%
data_v.isna().sum()
# Out:
# date        0
# group       0
# visitors    0
# dtype: int64

# %% [markdown]
# **Вывод:** пропуски отсутствуют.

# %% [markdown]
# **Общий вывод по разделу:** в данном разделе мы загрузили все датасеты и предобработали их. Датасеты готовы для дальнейшего анализа.

# %% [markdown]
# ## Приоритизация гипотез.

# %% [markdown]
# ### Применим фреймворк ICE для приоритизации гипотез.

# %% [markdown]
# 1. Создадим новый столбец 'ICE' в датасете 'data_h', в который запишем приоритет каждой гипотезы.

# %%
data_h['ICE'] = (data_h['impact'] * data_h['confidence']) / data_h['efforts']
data_h
# Out:
#                                           hypothesis  reach  impact  \
# 0  Добавить два новых канала привлечения трафика,...      3      10
# 1  Запустить собственную службу доставки, что сок...      2       5
# 2  Добавить блоки рекомендаций товаров на сайт ин...      8       3
# 3  Изменить структура категорий, что увеличит кон...      8       3
# 4  Изменить цвет фона главной страницы, чтобы уве...      3       1
# 5  Добавить страницу отзывов клиентов о магазине,...      3       2
# 6  Показать на главной странице баннеры с актуаль...      5       3
# 7  Добавить форму подписки на все основные страни...     10       7
# 8  Запустить акцию, дающую скидку на товар в день...      1       9
#
#    confidence  efforts        ICE
# 0           8        6  13.333333
# 1           4       10   2.000000
# 2           7        3   7.000000
# 3           3        8   1.125000
# 4           1        1   1.000000
# 5           2        3   1.333333
# 6           8        3   8.000000
# ...

# %% [markdown]
# 2. Отсортируем полученную таблицу по приоритету 'ICE' и выведем только два столбца с названием и приоритетом.

# %%
ice_table = data_h[['hypothesis', 'ICE']].sort_values(by='ICE', ascending=False)
ice_table
# Out:
#                                           hypothesis        ICE
# 8  Запустить акцию, дающую скидку на товар в день...  16.200000
# 0  Добавить два новых канала привлечения трафика,...  13.333333
# 7  Добавить форму подписки на все основные страни...  11.200000
# 6  Показать на главной странице баннеры с актуаль...   8.000000
# 2  Добавить блоки рекомендаций товаров на сайт ин...   7.000000
# 1  Запустить собственную службу доставки, что сок...   2.000000
# 5  Добавить страницу отзывов клиентов о магазине,...   1.333333
# 3  Изменить структура категорий, что увеличит кон...   1.125000
# 4  Изменить цвет фона главной страницы, чтобы уве...   1.000000

# %% [markdown]
# **Вывод:** по выведенной таблице видно, что наибольший приоритет у гипотезы, связанной с запуском акции. Также, не менее важной гипотезой является добавление двух новых каналов привлечения трафика и добавление формы подписки на все основные страницы. Менее всего приоритет у гипотезы, связанной с изменением цвета фона главной страницы.

# %% [markdown]
# ### Применим фреймворк RICE для приоритизации гипотез.

# %% [markdown]
# 1. Создадим новый столбец 'RICE' в датасете 'data_h', в который запишем приоритет каждой гипотезы.

# %%
data_h['RICE'] = (data_h['reach'] * data_h['impact'] * data_h['confidence']) / data_h['efforts']
data_h
# Out:
#                                           hypothesis  reach  impact  \
# 0  Добавить два новых канала привлечения трафика,...      3      10
# 1  Запустить собственную службу доставки, что сок...      2       5
# 2  Добавить блоки рекомендаций товаров на сайт ин...      8       3
# 3  Изменить структура категорий, что увеличит кон...      8       3
# 4  Изменить цвет фона главной страницы, чтобы уве...      3       1
# 5  Добавить страницу отзывов клиентов о магазине,...      3       2
# 6  Показать на главной странице баннеры с актуаль...      5       3
# 7  Добавить форму подписки на все основные страни...     10       7
# 8  Запустить акцию, дающую скидку на товар в день...      1       9
#
#    confidence  efforts        ICE   RICE
# 0           8        6  13.333333   40.0
# 1           4       10   2.000000    4.0
# 2           7        3   7.000000   56.0
# 3           3        8   1.125000    9.0
# 4           1        1   1.000000    3.0
# ...

# %% [markdown]
# 2. Отсортируем полученную таблицу по приоритету 'RICE' и выведем только два столбца с названием и приоритетом.

# %%
rice_table = data_h[['hypothesis', 'RICE']].sort_values(by='RICE', ascending=False)
rice_table
# Out:
#                                           hypothesis   RICE
# 7  Добавить форму подписки на все основные страни...  112.0
# 2  Добавить блоки рекомендаций товаров на сайт ин...   56.0
# 0  Добавить два новых канала привлечения трафика,...   40.0
# 6  Показать на главной странице баннеры с актуаль...   40.0
# 8  Запустить акцию, дающую скидку на товар в день...   16.2
# 3  Изменить структура категорий, что увеличит кон...    9.0
# 1  Запустить собственную службу доставки, что сок...    4.0
# 5  Добавить страницу отзывов клиентов о магазине,...    4.0
# 4  Изменить цвет фона главной страницы, чтобы уве...    3.0

# %% [markdown]
# **Вывод:** по выведенной таблице видно, что наибольший приоритет с большой разницой у гипотезы, связанной с добавлением формы подписки на все основные страницы. Также, не менее важными гипотезами являются добавление блока рекомендаций товара, добавление двух новых каналов привлечения трафика и показ на главной странице баннеров с актуальными акциями. Менее всего приоритет у гипотезы, связанной с изменением цвета фона главной страницы.

# %% [markdown]
# ### Изменение приоритизации гипотез при применении RICE вместо ICE.

# %% [markdown]
# 1. Для наглядности выведем обе таблицы.

# %%
ice_table
# Out:
#                                           hypothesis        ICE
# 8  Запустить акцию, дающую скидку на товар в день...  16.200000
# 0  Добавить два новых канала привлечения трафика,...  13.333333
# 7  Добавить форму подписки на все основные страни...  11.200000
# 6  Показать на главной странице баннеры с актуаль...   8.000000
# 2  Добавить блоки рекомендаций товаров на сайт ин...   7.000000
# 1  Запустить собственную службу доставки, что сок...   2.000000
# 5  Добавить страницу отзывов клиентов о магазине,...   1.333333
# 3  Изменить структура категорий, что увеличит кон...   1.125000
# 4  Изменить цвет фона главной страницы, чтобы уве...   1.000000

# %%
rice_table
# Out:
#                                           hypothesis   RICE
# 7  Добавить форму подписки на все основные страни...  112.0
# 2  Добавить блоки рекомендаций товаров на сайт ин...   56.0
# 0  Добавить два новых канала привлечения трафика,...   40.0
# 6  Показать на главной странице баннеры с актуаль...   40.0
# 8  Запустить акцию, дающую скидку на товар в день...   16.2
# 3  Изменить структура категорий, что увеличит кон...    9.0
# 1  Запустить собственную службу доставки, что сок...    4.0
# 5  Добавить страницу отзывов клиентов о магазине,...    4.0
# 4  Изменить цвет фона главной страницы, чтобы уве...    3.0

# %% [markdown]
# **Фреймворк ICE состоит из трёх компонент:**
# * Impact — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# * Confidence — насколько вы уверены, что это изменение повлияет на пользователей именно так;
# * Efforts — сколько стоит протестировать эту гипотезу.
#
#
# **Фреймворк RICE состоит из четырёх компонент:**
# * Reach — скольких пользователей затронет изменение, которое вы хотите внести;
# * Impact — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# * Confidence — насколько вы уверены, что это изменение повлияет на пользователей именно так;
# * Efforts — сколько стоит протестировать эту гипотезу.
#
#
# Во фреймворке ICE не учитывается компонент Reach, который показывает скольких пользователей затронет изменение. Поэтому в таблицах показатели отличаются.
#
#
# Рассмотрим таблицу с фреймворком RICE. Мы видим, что самый наибольший приоритет у гипотезы, связанной с добавлением формы подписки на все основные страницы (112 пунктов). Мы понимаем, что если мы добавляем какой-либо элемент на основную страницу, то обновление затронет практически всех пользователей сайта, поэтому приоритет растет. Если мы взглянем на таблицу с фреймворком ICE, то заметим, что данная гипотеза занимает только третье место по приоритету, так как показатель Reach не был учтён.

# %% [markdown]
# ## Анализ A/B-теста.

# %% [markdown]
# ### Построим график кумулятивной выручки по группам.

# %% [markdown]
# 1. Объединим обе таблицы (data_o и data_v) в одну с понятными названиями столбцов.

# %%
# создаем массив уникальных пар значений дат и групп теста
datesGroups = data_o[['date','group']].drop_duplicates()

# получаем агрегированные кумулятивные по дням данные о заказах 
ordersAggregated = datesGroups.apply(lambda x: data_o[np.logical_and(data_o['date'] <= x['date'], data_o['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'transaction_id' : 'nunique', 'visitor_id' : 'nunique', 'revenue' : 'sum'}), axis=1).sort_values(by=['date','group'])

# получаем агрегированные кумулятивные по дням данные о посетителях интернет-магазина 
visitorsAggregated = datesGroups.apply(lambda x: data_v[np.logical_and(data_v['date'] <= x['date'], data_v['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group'])

# объединяем кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия
cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# %% [markdown]
# 2. На основе объединенной таблицы строим график.

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
plt.figure(figsize=(15, 6))
plt.grid()
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]

# Строим график выручки группы А
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')

# Строим график выручки группы B
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')

# Настройка меток оси x
plt.xticks(rotation=45)  # поворот меток на 45 градусов
plt.xticks(cumulativeRevenueA['date'][::7])

# Настройка названий осей
plt.title('График кумулятивной выручки по группам')
plt.xlabel('Дата')
plt.ylabel('Выручка, тыс. руб.')

plt.legend()

# %% [markdown]
# **Вывод:** по выведенному графику мы видим, что группа А в течение всего времени стабильно растет без координальных скачков по показателям, предполагаю, что эта группа не подверагалсь каким-либо изменениям или не было совершено аномальных покупок. По графику, показывающего выручку группы В, мы видим, что присуствует скачок в уровне выручки за короткий промежуток времени, возможно, в этот период, было введено обновление, которое промотивировало пользователей купить товары в нашем интернет магазине или же в этот промежуток времени были совершены аномальные заказы, отличные от средних показателей.

# %% [markdown]
# ### Построим график кумулятивного среднего чека по группам.

# %% [markdown]
# 1. Чтобы определить средний чек, необходимо выручку по дням разделить на количество заказов. Нарисуем график.

# %%
# Строим график
plt.figure(figsize=(15, 6))
plt.grid()
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'] / cumulativeRevenueA['orders'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'] / cumulativeRevenueB['orders'], label='B')

# Настройка названий осей
plt.title('График кумулятивного среднего чека по группам')
plt.xlabel('Дата')
plt.ylabel('Средний чек')

# Настройка меток оси x
plt.xticks(rotation=45)  # поворот меток на 45 градусов
plt.xticks(cumulativeRevenueA['date'][::7])
plt.legend()

# %% [markdown]
# **Вывод:** по выведенному графику мы видим, что показатели среднего чека группы А с начала периода анализа падают до минимума, менее 5000, затем начинают стремительно расти до отметки ±7500 (максимум), затем ситуация по показателям стабилизируется и средний чек держится примерно на одном и том же уровне. Ситуация с группой В иная - в начале периода анализа показатель среднего чека постепенно растет, также, встречаются несущественные просадки по показателям. Но за короткий промежуток времени, показатель среднего чека возрастает на ±3000, могу предположить, что в этот промежуток времени вышло какое-то обновление, которое заинтересовало клиентов купить товар в нашем интернет магазине или же в этот промежуток времени были совершены аномальные заказы, отличные от средних показателей.

# %% [markdown]
# ### Построим график относительного изменения кумулятивного среднего чека группы B к группе A.

# %%
# собираем данные в одном датафрейме
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

# cтроим отношение средних чеков
plt.figure(figsize=(15, 6))
plt.grid()

# Настройка названий осей
plt.title('График относительного изменения кумулятивного среднего чека группы B к группе A')
plt.xlabel('Дата')
plt.ylabel('Доля')
plt.plot(mergedCumulativeRevenue['date'], (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])/(mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1)

# добавляем ось X
plt.axhline(y=0, color='black', linestyle='--') 

# Настройка меток оси x
plt.xticks(rotation=45)  # поворот меток на 45 градусов
plt.xticks(cumulativeRevenueA['date'][::7])
# Out:
# ([<matplotlib.axis.XTick at 0x7f5ce4b98850>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# **Вывод:** В нескольких точках график различия между сегментами резко «скачет», видимо тогда были совершены аномальные заказы. Но в основном график расположен выше нуля.

# %% [markdown]
# ### Построим график кумулятивного среднего количества заказов на посетителя по группам.

# %%
# считаем кумулятивную конверсию
cumulativeData['conversion'] = cumulativeData['orders']/cumulativeData['visitors']

# отделяем данные по группе A
cumulativeDataA = cumulativeData[cumulativeData['group']=='A']

# отделяем данные по группе B
cumulativeDataB = cumulativeData[cumulativeData['group']=='B']

# строим графики
plt.figure(figsize=(15, 6))
plt.grid()

plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label='A')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label='B')

# Настройка названий осей
plt.title('График кумулятивного среднего количества заказов на посетителя по группам')
plt.xlabel('Дата')
plt.ylabel('Среднее количество заказов на пользователя')

# Настройка меток оси x
plt.xticks(rotation=45)  # поворот меток на 45 градусов
plt.xticks(cumulativeRevenueA['date'][::7])

plt.legend()

# %% [markdown]
# **Вывод:** по выведенному графику, мы можем заметить, что конверсия группы B выше, чем у А. В начале периода анализа мы видим, что у группы A большой скачок по показателям, выше, чем у группы B, но в течение короткого времени показатели снижаются и держатся на уровне от 0.029 - 0.031. У группы В cитуация иная - после скачка вниз, показатели повышаются и держатся на уровне 0.033 - 0.036.

# %% [markdown]
# ### Построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе А.

# %%
mergedCumulativeConversions = cumulativeDataA[['date','conversion']].merge(cumulativeDataB[['date','conversion']], left_on='date', right_on='date', how='left', suffixes=['A', 'B'])
#строим график
plt.figure(figsize=(15, 10))
plt.plot(mergedCumulativeConversions['date'], mergedCumulativeConversions['conversionB']/mergedCumulativeConversions['conversionA']-1, label="Относительный прирост конверсии группы B относительно группы A")
# добавляем оси
plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=0.15, color='grey', linestyle='--')
plt.title('График относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A')
plt.xlabel('Дата')
plt.ylabel('Среднее количество заказов на посетителя')
# Настройка меток оси x
plt.xticks(rotation=45)  # поворот меток на 45 градусов
plt.xticks(cumulativeRevenueA['date'][::7])

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **Вывод:** по графику видно, что примерно на 5 день, конверсия группы В начинает лидировать, приимерно на 15%.

# %% [markdown]
# ### Построим точечный график количества заказов по пользователям.

# %%
ordersByUsers = (
    data_o.groupby('visitor_id', as_index=False)
    .agg({'transaction_id': 'nunique'})
)
ordersByUsers.columns = ['userId', 'orders']

# серия из чисел от 0 до количества наблюдений в ordersByUsers
x_values = pd.Series(range(0, len(ordersByUsers)))

# Строим график
plt.figure(figsize=(10, 7))
plt.grid()
plt.scatter(x_values, ordersByUsers['orders']) 

# Настройка названий осей
plt.title('Точечный график количества заказов по пользователям')
plt.xlabel('Частота')
plt.ylabel('Количество заказов')
# Out:
# Text(0, 0.5, 'Количество заказов')

# %% [markdown]
# **Вывод:** по графику видно, что количество пользователей, совершивших больше двух заказов не так много, стоит задуматься над привлечением пользователей совершать больше заказов.

# %% [markdown]
# ### Посчитаем 95-й и 99-й перцентили количества заказов на пользователя.

# %% [markdown]
# 1. С помощью метода np.percentile() найдем 5-й и 99-й перцентили количества заказов на пользователя.

# %%
print(np.percentile(ordersByUsers['orders'], [95, 99]))
# Out:
# [2. 4.]

# %% [markdown]
# **Вывод:** менее 5% пользователей совершили более 2 заказов, а менее 1% пользователей сделали более 4 заказов.

# %%
data_o
# Out:
#       transaction_id  visitor_id        date  revenue group
# 0         3667963787  3312258926  2019-08-15     1650     B
# 1         2804400009  3642806036  2019-08-15      730     B
# 2         2961555356  4069496402  2019-08-15      400     A
# 3         3797467345  1196621759  2019-08-15     9759     B
# 4         2282983706  2322279887  2019-08-15     2308     B
# ...              ...         ...         ...      ...   ...
# 1192      2662137336  3733762160  2019-08-14     6490     B
# 1193      2203539145   370388673  2019-08-14     3190     A
# 1194      1807773912   573423106  2019-08-14    10550     A
# 1195      1947021204  1614305549  2019-08-14      100     A
# 1196      3936777065  2108080724  2019-08-15   202740     B
#
# [1197 rows x 5 columns]

# %% [markdown]
# ### Построим точечный график стоимостей заказов.

# %%
x_values = pd.Series(range(0, len(data_o['revenue'])))
plt.figure(figsize=(10, 7))
plt.scatter(x_values, data_o['revenue'])

# %% [markdown]
# **Вывод:** по графику видно, что в данных присутствуют аномалии - заказы на 1.2 млн. руб. и 200 тыс. руб.

# %% [markdown]
# ### Посчитаем 95-й и 99-й перцентили стоимости заказов.

# %%
print(np.percentile(data_o['revenue'] , [95, 99]))
# Out:
# [28000.  58233.2]

# %% [markdown]
# **Вывод:** из выведенных данных видим, что 5% пользователей заказали товаров на более чем 28.000 рублей, а 1% пользователей приобрели товаров в нашем магазине на сумму выше 58233.2 рублей.

# %%
data_o
# Out:
#       transaction_id  visitor_id        date  revenue group
# 0         3667963787  3312258926  2019-08-15     1650     B
# 1         2804400009  3642806036  2019-08-15      730     B
# 2         2961555356  4069496402  2019-08-15      400     A
# 3         3797467345  1196621759  2019-08-15     9759     B
# 4         2282983706  2322279887  2019-08-15     2308     B
# ...              ...         ...         ...      ...   ...
# 1192      2662137336  3733762160  2019-08-14     6490     B
# 1193      2203539145   370388673  2019-08-14     3190     A
# 1194      1807773912   573423106  2019-08-14    10550     A
# 1195      1947021204  1614305549  2019-08-14      100     A
# 1196      3936777065  2108080724  2019-08-15   202740     B
#
# [1197 rows x 5 columns]

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.

# %% [markdown]
# 1. Сформулируем гипотезы.
#
# * H0: различий в среднем количестве заказов между группами нет.
# * H1: различия в среднем между группами есть.
# * Уровень значимости альфа = 0.05

# %%
visitorsADaily = data_v[data_v['group'] == 'A'][['date', 'visitors']]
visitorsADaily.columns = ['date', 'visitorsPerDateA']

visitorsACummulative = visitorsADaily.apply(
    lambda x: visitorsADaily[visitorsADaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateA': 'sum'}
    ),
    axis=1,
)
visitorsACummulative.columns = ['date', 'visitorsCummulativeA']

visitorsBDaily = data_v[data_v['group'] == 'B'][['date', 'visitors']]
visitorsBDaily.columns = ['date', 'visitorsPerDateB']

visitorsBCummulative = visitorsBDaily.apply(
    lambda x: visitorsBDaily[visitorsBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateB': 'sum'}
    ),
    axis=1,
)
visitorsBCummulative.columns = ['date', 'visitorsCummulativeB']

ordersADaily = (
    data_o[data_o['group'] == 'A'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
ordersADaily.columns = ['date', 'ordersPerDateA', 'revenuePerDateA']

ordersACummulative = ordersADaily.apply(
    lambda x: ordersADaily[ordersADaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateA': 'sum', 'revenuePerDateA': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersACummulative.columns = [
    'date',
    'ordersCummulativeA',
    'revenueCummulativeA',
]

ordersBDaily = (
    data_o[data_o['group'] == 'B'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
ordersBDaily.columns = ['date', 'ordersPerDateB', 'revenuePerDateB']

ordersBCummulative = ordersBDaily.apply(
    lambda x: ordersBDaily[ordersBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateB': 'sum', 'revenuePerDateB': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersBCummulative.columns = [
    'date',
    'ordersCummulativeB',
    'revenueCummulativeB',
]

data = (
    ordersADaily.merge(
        ordersBDaily, left_on='date', right_on='date', how='left'
    )
    .merge(ordersACummulative, left_on='date', right_on='date', how='left')
    .merge(ordersBCummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsADaily, left_on='date', right_on='date', how='left')
    .merge(visitorsBDaily, left_on='date', right_on='date', how='left')
    .merge(visitorsACummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsBCummulative, left_on='date', right_on='date', how='left')
)

print(data.head(5))
# Out:
#          date  ordersPerDateA  revenuePerDateA  ordersPerDateB  \
# 0  2019-08-01              24           148579              21
# 1  2019-08-02              20            93822              24
# 2  2019-08-03              24           112473              16
# 3  2019-08-04              16            70825              17
# 4  2019-08-05              25           124218              23
#
#    revenuePerDateB  ordersCummulativeA  revenueCummulativeA  \
# 0           101217                  24               148579
# 1           165531                  44               242401
# 2           114248                  68               354874
# 3           108571                  84               425699
# 4            92428                 109               549917
#
#    ordersCummulativeB  revenueCummulativeB  visitorsPerDateA  \
# 0                  21               101217               719
# 1                  45               266748               619
# ...

# %% [markdown]
# * ordersPerDateA — количество заказов в выбранную дату в группе A;
# * revenuePerDateA — суммарная выручка в выбранную дату в группе A;
# * ordersPerDateB — количество заказов в выбранную дату в группе B;
# * revenuePerDateB — суммарная выручка в выбранную дату в группе B;
# * ordersCummulativeA — суммарное число заказов до выбранной даты включительно в группе A;
# * revenueCummulativeA — суммарная выручка до выбранной даты включительно в группе A;
# * ordersCummulativeB — суммарное количество заказов до выбранной даты включительно в группе B;
# * revenueCummulativeB — суммарная выручка до выбранной даты включительно в группе B;
# * visitorsPerDateA — количество пользователей в выбранную дату в группе A;
# * visitorsPerDateB — количество пользователей в выбранную дату в группе B;
# * visitorsCummulativeA — количество пользователей до выбранной даты включительно в группе A;
# * visitorsCummulativeB — количество пользователей до выбранной даты включительно в группе B.

# %% [markdown]
# 2. Создадим переменные ordersByUsersA и ordersByUsersB со столбцами ['visitor_id', 'orders']. В них для пользователей, которые заказывали хотя бы 1 раз, укажем число совершённых заказов.

# %%
ordersByUsersA = (
    data_o[data_o['group'] == 'A']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
ordersByUsersA.columns = ['visitor_id', 'orders']

ordersByUsersB = (
    data_o[data_o['group'] == 'B']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
ordersByUsersB.columns = ['visitor_id', 'orders']

# %% [markdown]
# 3. Объявим переменные sampleA и sampleB, в которых пользователям из разных групп будет соответствовать количество заказов. Тем, кто ничего не заказал, будут соответствовать нули. Это нужно, чтобы подготовить выборки к проверке критерием Манна-Уитни.

# %%
sampleA = pd.concat(
    [
        ordersByUsersA['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleB = pd.concat(
    [
        ordersByUsersB['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

print("{0:.3f}".format(stats.mannwhitneyu(sampleA, sampleB)[1]))

print("{0:.3f}".format(sampleB.mean() / sampleA.mean() - 1))
# Out:
# 0.017
# 0.138

# %% [markdown]
# **Вывод:** P-value меньше 0.05 — это меньше заданного уровня значимости. Разница между выборками имеет значимый характер. Следовательно можно утверждать, что разница в среднем количестве заказов на посетителя между группами есть. Тот результат, который имеет на графике не может быть получен случайно. Относительное различие среднего чека между сегментами 13.8%

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.

# %% [markdown]
# 1. Сформулируем гипотезы.
#
# * H0: различий в среднем чеке между группами нет.
# * H1: различия в среднем чеке между группами есть.
# * Уровень значимости альфа = 0.05

# %% [markdown]
# 2. Чтобы рассчитать статистическую значимость различий в среднем чеке, передадим критерию mannwhitneyu() данные о выручке с заказов.

# %%
print('{0:.3f}'.format(stats.mannwhitneyu(data_o[data_o['group']=='A']['revenue'], data_o[data_o['group']=='B']['revenue'])[1]))
print('{0:.3f}'.format(data_o[data_o['group']=='B']['revenue'].mean()/data_o[data_o['group']=='A']['revenue'].mean()-1))
# Out:
# 0.729
# 0.259

# %% [markdown]
# **Вывод:** P-value значительно больше 0.05. Значит, причин отвергать нулевую гипотезу и считать, что в среднем чеке есть различия, нет. Относительный прирост группы В по среднему чеку заказа составил 25.9%.

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным.

# %% [markdown]
# 1. Примем за аномальных пользователей тех, кто совершил от 3 заказов или совершил заказ дороже 40 000 рублей. Так мы уберём 2.5% пользователей с наибольшим числом заказов и 2.5% пользователей с дорогими заказами.

# %%
usersWithManyOrders = pd.concat(
    [
        ordersByUsersA[ordersByUsersA['orders'] > 3]['visitor_id'],
        ordersByUsersB[ordersByUsersB['orders'] > 3]['visitor_id'],
    ],
    axis=0,
)
usersWithExpensiveOrders = data_o[data_o['revenue'] > 40000]['visitor_id']
abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)
print(abnormalUsers.head(5))
print(abnormalUsers.shape[0])
# Out:
# 1099    148427295
# 18      199603092
# 23      237748145
# 684     358944393
# 648     382846391
# Name: visitor_id, dtype: int64
# 34

# %% [markdown]
# Всего 34 аномальных visitor_id в нашем датасете.

# %% [markdown]
# 2. Посчитаем статистическую значимость различий в среднем количестве заказов между группами теста по очищенным данным. Сначала подготовим выборки количества заказов по пользователям по группам теста:

# %%
sampleAFiltered = pd.concat(
    [
        ordersByUsersA[
            np.logical_not(ordersByUsersA['visitor_id'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleBFiltered = pd.concat(
    [
        ordersByUsersB[
            np.logical_not(ordersByUsersB['visitor_id'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# %% [markdown]
# 3. Применим статистический критерий Манна-Уитни к полученным выборкам.

# %%
print('{0:.3f}'.format(stats.mannwhitneyu(sampleAFiltered, sampleBFiltered)[1]))
print('{0:.3f}'.format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# 0.009
# 0.164

# %% [markdown]
# **Вывод:** Аномалии не повлияли на статистическую значимость. По очищенным данным P-value уменьшился с 1.7%% до 0.9%.
# Относительный прирост группы В к группе А увеличился с 13.8% до 16.4%

# %% [markdown]
# ### Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным.

# %%
print(
    '{0:.3f}'.format(
        stats.mannwhitneyu(
            data_o[
                np.logical_and(
                    data_o['group'] == 'A',
                    np.logical_not(data_o['visitor_id'].isin(abnormalUsers)),
                )
            ]['revenue'],
            data_o[
                np.logical_and(
                    data_o['group'] == 'B',
                    np.logical_not(data_o['visitor_id'].isin(abnormalUsers)),
                )
            ]['revenue'],
        )[1]
    )
)

print(
    "{0:.3f}".format(
        data_o[
            np.logical_and(
                data_o['group'] == 'B',
                np.logical_not(data_o['visitor_id'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        / data_o[
            np.logical_and(
                data_o['group'] == 'A',
                np.logical_not(data_o['visitor_id'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# 0.711
# 0.060

# %% [markdown]
# **Вывод:** Статистической разницы между "очищенными" и "сырыми" данными нет. p_value уменьшился с 72.9% до 71.1%
# Относительный прирост группы В к группе А уменьшился с 26% до 6%

# %% [markdown]
# ## Вывод. Принятие решения по результатам теста.

# %% [markdown]
# **1. В ходе исследования данных, связанных с интернет магазином была проделана большая работа:**
# * В первую очередь мы загрузили все данные и их предобработали.
# *  Датафреймы были проверены на явные/неявные дубликаты, а также на пропуски.
# * Некорректные названия столбцов были изменены на правильные.
#
# **2. Были выбраны самые приоритетные гипотезы с помощью RICE и ICE фреймворков:**
# * Наибольший приоритет у гипотезы ICE фреймворка, связанной с запуском акции. Также, не менее важной гипотезой является добавление двух новых каналов привлечения трафика и добавление формы подписки на все основные страницы. Менее всего приоритет у гипотезы, связанной с изменением цвета фона главной страницы.
# * Наибольший приоритет с большой разницой у гипотезы, связанной с добавлением формы подписки на все основные страницы. Также, не менее важными гипотезами являются добавление блока рекомендаций товара, добавление двух новых каналов привлечения трафика и показ на главной странице баннеров с актуальными акциями. Менее всего приоритет у гипотезы, связанной с изменением цвета фона главной страницы.
#
#
# **Фреймворк ICE состоит из трёх компонент:**
# * Impact — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# * Confidence — насколько вы уверены, что это изменение повлияет на пользователей именно так;
# * Efforts — сколько стоит протестировать эту гипотезу.
#
#
# **Фреймворк RICE состоит из четырёх компонент:**
# * Reach — скольких пользователей затронет изменение, которое вы хотите внести;
# * Impact — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# * Confidence — насколько вы уверены, что это изменение повлияет на пользователей именно так;
# * Efforts — сколько стоит протестировать эту гипотезу.
#
#
# **Вывод:** во фреймворке ICE не учитывается компонент Reach, который показывает скольких пользователей затронет изменение. Поэтому в таблицах показатели отличаются.
#
#
#
# **3. Провели анализ А/В теста и можем сделать выводы:**
#
#
# **По графикам кумулятивного расчета:**
# * **График кумулятивной выручки по группам.** Показатели выручки группы А в течение всего времени стабильно растут без координальных скачков по показателям, предполагаю, что эта группа не подверагалсь каким-либо изменениям или не было совершено аномальных покупок. По графику, показывающего кумулятивную выручку группы присуствует скачок в уровне выручки за короткий промежуток времени, возможно, в этот период, было введено обновление, которое промотивировало пользователей купить товары в нашем интернет магазине или же в этот промежуток времени были совершены аномальные заказы, отличные от средних показателей.
# * **График кумулятивного среднего чека по группам.** Показатели среднего чека группы А с начала периода анализа падают до минимума, менее 5000, затем начинают стремительно расти до отметки ±7500 (максимум), затем ситуация по показателям стабилизируется и средний чек держится примерно на одном и том же уровне. Ситуация с группой В иная - в начале периода анализа показатель среднего чека постепенно растет, также, встречаются несущественные просадки по показателям. Но за короткий промежуток времени, показатель среднего чека возрастает на ±3000, могу предположить, что в этот промежуток времени вышло какое-то обновление, которое заинтересовало клиентов купить товар в нашем интернет магазине или же в этот промежуток времени были совершены аномальные заказы, отличные от средних показателей.
# * **График относительного изменения кумулятивного среднего чека группы B к группе A.** В нескольких точках график различия между группами резко «скачет», видимо тогда были совершены аномальные заказы.
# * **График кумулятивного среднего количества заказов на посетителя по группам.** Конверсия группы B выше, чем у А. В начале периода анализа мы видим, что у группы A большой скачок по показателям, выше, чем у группы B, но в течение короткого времени показатели снижаются и держатся на уровне от 0.029 - 0.031. У группы В cитуация иная - после скачка вниз, показатели повышаются и держатся на уровне 0.033 - 0.036.
# * **График кумулятивного среднего количества заказов на посетителя по группам.** Примерно на 5 день, конверсия группы В начинает лидировать, приимерно на 15%.
# * **Точечный график количества заказов по пользователям.** Количество пользователей, совершивших больше двух заказов не так много, стоит задуматься над привлечением пользователей совершать больше заказов.
#
#
#
# **Была подсчитана статистическая значимость различий в среднем чеке заказа между группами по «очищенным» и "сырым" данным:**
#
# * Статистической разницы между "очищенными" и "сырыми" данными нет. p_value уменьшился с 72.9% до 71.1%.
# * Относительный прирост группы В к группе А уменьшился с 26% до 6%
#
#
# **Была подсчитана статистическая значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» и "сырым" данным:**
#
# * Аномалии особо не повлияли на статистическую значимость. По очищенным данным p_value уменьшился с 1.7% до 0.9%
# * Относительный прирост группы В к группе А увеличился с 13.8% до 16.4%
#
#
# **Имеющиеся факты:**
# * Есть статистически значимое различие по среднему количеству заказов между группами и по «сырым», и по данным после фильтрации аномалий.
# * Нет статистически значимого различия по среднему чеку между группами ни по «сырым», ни по данным после фильтрации аномалий.
# * График различия среднего количества заказов между группами сообщает, что результаты группы B лучше группы A, но есть небольшая тенденция к ухудшению.
# * График различия среднего чека говорит о том, что результаты группы B имеет резкие колебания в течение всего периода.
# * По результатам исследования, можно утверждать, что различия среднего количества заказов между группами имеют статистическую значимость. То есть разница получена не случайным образом, а она действительно есть. Таким образом, количество заказов увеличилось, а средний чек остался прежним. Выручка увеличивается.
#
# **Ключевой вывод:** Исходя из обнаруженных фактов, тест следует остановить и зафиксировать победу группы В.
